# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
from datetime import date
import requests as rq
from bs4 import BeautifulSoup
from time import sleep

#定义中金所数据端口
url = 'http://www.cffex.com.cn/sj/historysj/'

#根据数据端口特征创建目标月份表单
def generate_month_list(start_month_str, end_month_str):
    """
    生成指定月份范围的月份列表。

    Args:
        start_month_str: 起始月份字符串，格式为 'YYYYMM'。
        end_month_str: 结束月份字符串，格式为 'YYYYMM'。

    Returns:
        月份列表，格式为 'YYYYMM' 的字符串列表。
        如果输入格式错误或起始月份晚于结束月份，则返回空列表。
    """
    try:
        start_year = int(start_month_str[:4])
        start_month = int(start_month_str[4:])
        end_year = int(end_month_str[:4])
        end_month = int(end_month_str[4:])

        if start_year > end_year or (start_year == end_year and start_month > end_month):
            return []

        month_list = []
        current_year = start_year
        current_month = start_month

        while current_year < end_year or (current_year == end_year and current_month <= end_month):
            month_str = f"{current_year:04d}{current_month:02d}"
            month_list.append(month_str)

            current_month += 1
            if current_month > 12:
                current_month = 1
                current_year += 1

        return month_list

    except ValueError:
        return [] # 处理输入格式错误

#创建下载器
def download(url):
    try:
        response = rq.get(url)
        response.raise_for_status()
        sleep(10)
        
        save_path = 'D:\\ChromeDownloads\\Futures_exchange_data\\CFFEX\\' + url[-10:]
        with open(save_path, 'wb') as f:
            f.write(response.content)

        print(f'File saved as: {save_path}')

    except rq.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
    except IOError as e:
        print(f"Error saving file: {e}")

#根据端口特征创建的目标月份列表
start_month = '201004'
end_month = '202412'
month_list = generate_month_list(start_month, end_month)

#拼合url与目标文件创建下载地址列表
Dlink = [url + str(i + '/zip/' + i + '.zip') for i in month_list]
['http://www.cffex.com.cn/sj/historysj/201004/zip/201004.zip'

#开始下载
for i in Dlink:
    download(i)
# Out:
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201004.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201005.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201006.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201007.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201008.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201009.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201010.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201011.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201012.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201101.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201102.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201103.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201104.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201105.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201106.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201107.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201108.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201109.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201110.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201111.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201112.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201201.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201202.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201203.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201204.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201205.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201206.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201207.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201208.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201209.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201210.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201211.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201212.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201301.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201302.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201303.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201304.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201305.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201306.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201307.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201308.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201309.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201310.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201311.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201312.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201401.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201402.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201403.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201404.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201405.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201406.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201407.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201408.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201409.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201410.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201411.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201412.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201501.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201502.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201503.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201504.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201505.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201506.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201507.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201508.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201509.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201510.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201511.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201512.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201601.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201602.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201603.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201604.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201605.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201606.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201607.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201608.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201609.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201610.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201611.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201612.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201701.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201702.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201703.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201704.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201705.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201706.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201707.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201708.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201709.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201710.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201711.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201712.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201801.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201802.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201803.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201804.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201805.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201806.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201807.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201808.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201809.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201810.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201811.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201812.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201901.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201902.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201903.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201904.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201905.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201906.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201907.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201908.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201909.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201910.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201911.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\201912.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202001.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202002.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202003.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202004.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202005.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202006.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202007.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202008.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202009.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202010.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202011.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202012.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202101.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202102.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202103.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202104.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202105.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202106.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202107.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202108.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202109.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202110.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202111.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202112.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202201.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202202.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202203.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202204.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202205.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202206.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202207.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202208.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202209.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202210.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202211.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202212.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202301.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202302.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202303.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202304.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202305.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202306.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202307.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202308.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202309.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202310.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202311.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202312.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202401.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202402.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202403.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202404.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202405.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202406.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202407.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202408.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202409.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202410.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202411.zip
# File saved as: D:\ChromeDownloads\Futures_exchange_data\CFFEX\202412.zip
